# %%
import asyncio
from urllib.parse import urljoin
from playwright.async_api import async_playwright
import nest_asyncio

async def get_qas_urls_async():
    async with async_playwright() as playwright:
        browser = await playwright.chromium.launch()
        page = await browser.new_page()
        base_url = "https://www.cite-sciences.fr/fr/ressources/juniors"
        await page.goto(base_url)

        web_experiences = []

        # SMART GAMES
        smart_games = await page.query_selector_all("#grid .item-grid.bgJunior")
        # Work with the filtered elements
        # print("SMART GAMES")
        for element in smart_games:
            title = await page.evaluate("el => el.querySelector('.titre').textContent", element)
            description = await page.evaluate("el => el.querySelector('.texte').innerText.trim()", element)
            # print("title:", title)
            # print("description:", description)
            href = await page.evaluate("el => el.querySelector('a')?.getAttribute('href')", element)
            absolute_url = urljoin(base_url, href)
            # print("Link href:", absolute_url)
            web_experiences.append({
                "title": title,
                "description": description,
                "url": absolute_url,
            })

        # TINKERING AND MANIPULATIONS
        # print("TINKERING AND MANIPULATIONS")
        tinkering_experiences = await page.query_selector_all("#grid .item-grid.bgLight")
        for element in tinkering_experiences:
            parent_title = await page.evaluate("el => el.querySelector('.titre').textContent", element)
            description = await page.evaluate("el => el.querySelector('.texte').innerText.trim()", element)
            # print("title:", title)
            # print("description:", description)
            href = await page.evaluate("el => el.querySelector('a')?.getAttribute('href')", element)
            absolute_url = urljoin(base_url, href)
            # print("Link href:", absolute_url)
            # 
            new_page = await browser.new_page()
            await new_page.goto(absolute_url)
            experiences = await new_page.query_selector_all("#grid .item-grid .contenu:has(a)")
            for experience in experiences:
                title = await new_page.evaluate("el => el.querySelector('.ce-bodytext>h3').textContent", experience)            
                description = await new_page.evaluate("""
                    (element) => {
                        const paragraphs = element.querySelectorAll('.ce-bodytext p');
                        return Array.from(paragraphs).map(p => p.innerText).join('\\n');
                    }
                """, experience)
                experience_url = await new_page.evaluate("""
                    (element) => {
                        const url = Array.from(element.querySelectorAll('.ce-bodytext a')).pop();
                        if (url) {
                            return url.getAttribute('href')
                        } else {
                            return "";
                        }
                    }
                """, experience)
                
                # print("========== title", title)
                # print("========== description", description)
                web_experiences.append({
                    "title": f"{parent_title} / {title}",
                    "description": description,
                    "type": "test",
                    "url": urljoin(absolute_url, experience_url),
                })

        for exp in web_experiences:
            print(exp)
            print('==============')
        await page.close()
        await browser.close()

def get_qas_urls():
    nest_asyncio.apply()
    loop = asyncio.get_event_loop()
    return loop.run_until_complete(get_qas_urls_async())

def main():
    get_qas_urls()

main()
# Out:
# {'title': 'Tranches de vie au Moyen Âge', 'description': "Remonte le temps jusqu'au Moyen Âge et découvre le travail des paysans, la nourriture des seigneurs et des paysans, la confection du drap de laine, le commerce, les voyages...", 'url': 'http://www.cite-sciences.fr/juniors/moyen-age/index.html'}
# ==============
# {'title': "Le froid ? C'est chaud !", 'description': "Fabrique un frigo du désert, devine des températures, classe des animaux selon qu'ils sont endothermes ou ectothermes, teste tes connaissances...", 'url': 'http://www.cite-sciences.fr/juniors/froid-chaud/index.html'}
# ==============
# {'title': 'Sur les pas de Darwin aux Galápagos', 'description': 'Tout en découvrant la faune et la flore des Galápagos, initie-toi à la classification des animaux, aux réseaux alimentaires, aux mécanismes de la sélection naturelle...', 'url': 'http://www.cite-sciences.fr/juniors/darwin-galapagos/index.html'}
# ==============
# {'title': 'Agriculture, alimentation / Guillaume, apprenti boulanger', 'description': "Suis Guillaume, jeune apprenti boulanger dans la France du 12e siècle, et découvre le travail des paysans, la fabrication du pain et l'alimentation des paysans et des nobles de cette époque.\n> Dès 8 ans\n> Jeu en HTML5, accessible au clavier, à la synthèse vocale avec contrastes des couleurs", 'type': 'test', 'url': 'http://www.cite-sciences.fr/juniors/moyen-age/guillaume-apprenti-boulanger.html'}
# ==============
# {'title': 'Agriculture, alimentation / Le quiz Moyen Âge', 'description': "Dix questions tirées aléatoirement parmi une soixantaine t'invitent à tester tes connaissances sur le second Moyen Âge : vie à la campagne et dans les villes, commerce, transports, diffusion des savoirs, travail des paysans, des artisans, des marchands...\n> Dès 9 ans\n> Jeu en HTML5, accessible au clavier, à la synthèse vocale avec contrastes des couleurs", 'type': 'test', 'url': 'http://www.cite-sciences.fr/juniors/moyen-age/quiz.html'}
# ==============
# {'title': 'Environnement, développement durable / Compteur climat en temps réel', 'description': "Quel volume de CO2 rejette-t-on dans l'atmosphère terrestre ? Combien de barils de pétrole brut produit-on ? Combien d’humains y a-t-il sur Terre ? Combien de piscines olympiques peut-on remplir avec la fonte des glaces du Groenland ?\xa0\nEt quelques autres indicateurs du changement climatique à découvrir en temps réel.\n> Dès 11 ans\n> Jeu en HTML5, accessible au clavier, à la synthèse vocale avec contrastes des couleurs", 'type': 'test', 'url': 'http://www.cite-sciences.fr/climat/applicompteurs/'}
# ==============
# {'title': 'Environnement, développement durable / Faisons vite, ça chauffe !', 'description': 'Qu’est-ce que le réchauffement climatique ? Quelle est sa cause ? Quelles sont ses conséquences ? Que peut-on faire pour le contenir ?\nUn quiz en 10 questions qui t’aide à comprendre ce phénomène.\n> Dès 9 ans', 'type': 'test', 'url': 'http://www.cite-sciences.fr/ressources-en-ligne/juniors/quiz-climat/index.php'}
# ==============
# {'title': 'Énergie, techniques, industrie / Le quiz des profondeurs', 'description': "L'endroit le plus profond de la planète se trouve dans la fosse des Mariannes (océan Pacifique), à près de 11 000 mètres sous le niveau de l'eau. Que sais-tu des animaux qui plongent ou vivent à ces profondeurs ? Ou encore des submersibles, qu'ils soient engins d'exploration ou sous-marins ?\n> Dès 9 ans\n> Jeu en HTML5, accessible au clavier, à la synthèse vocale, avec contrastes des couleurs\n", 'type': 'test', 'url': 'http://www.cite-sciences.fr/sous-locean/quiz/'}
# ==============
# {'title': 'Énergie, techniques, industrie / Fabrique un frigo du désert', 'description': 'Le frigo du désert est un dispositif très simple qui permet de conserver des légumes et des fruits sans électricité dans les pays chauds et secs. Toi aussi, fabrique un frigo du désert et découvre ce principe de refroidissement par évaporation.\n> Dès 9 ans\n> Jeu en HTML5, accessible au clavier, à la synthèse vocale, avec contrastes des couleurs', 'type': 'test', 'url': 'https://www.cite-sciences.fr/juniors/froid-chaud/fabrique-un-frigo-du-desert.html'}
# ==============
# {'title': 'Énergie, techniques, industrie / Quiz « Le froid ? C’est chaud ! »', 'description': 'Teste tes connaissances sur le froid, le chaud, la chaleur, les échelles de température, les moyens de défense des animaux face au froid...\n> Dès 9 ans\n> Jeu en HTML5, accessible au clavier, à la synthèse vocale, avec contrastes des couleurs', 'type': 'test', 'url': 'https://www.cite-sciences.fr/juniors/froid-chaud/quiz.html'}
# ==============
# {'title': 'Énergie, techniques, industrie / Marguerite, apprentie couturière', 'description': "Suis Marguerite, jeune apprentie couturière dans la France du 13e siècle et découvre la fabrication du drap de laine (tonte des moutons, traitement de la laine, filage, tissage, teinture) ainsi que l'habillement des paysans et des nobles.\n> Dès 9 ans\n> Jeu en HTML5, accessible au clavier, à la synthèse vocale avec contrastes des couleurs", 'type': 'test', 'url': 'http://www.cite-sciences.fr/juniors/moyen-age/marguerite-apprentie-couturiere.html'}
# ==============
# {'title': 'Énergie, techniques, industrie / Le quiz Moyen Âge', 'description': "Dix questions tirées aléatoirement parmi une soixantaine t'invitent à tester tes connaissances sur le second Moyen Âge : vie à la campagne et dans les villes, commerce, transports, diffusion des savoirs, travail des paysans, des artisans, des marchands...\n> Dès 9 ans\n> Jeu en HTML5, accessible au clavier, à la synthèse vocale avec contrastes des couleurs", 'type': 'test', 'url': 'http://www.cite-sciences.fr/juniors/moyen-age/quiz.html'}
# ==============
# {'title': 'Mathématiques, physique, chimie / Plus c’est chaud, plus ça bouge !', 'description': 'Ce petit film d’animation est non seulement rigolo, mais aussi très instructif ! Il explique par exemple que plus un objet est chaud, plus ses particules de matière sont agitées, et que la température d’un objet mesure cette agitation des particules. Quant à la chaleur, c’est différent...\n> Dès 9 ans\n> Film d’animation (2 min 49), player vidéo accessible au clavier, à la synthèse vocale', 'type': 'test', 'url': 'https://www.cite-sciences.fr/juniors/froid-chaud/plus-c-est-chaud-plus-ca-bouge.html'}
# ==============
# {'title': 'Mathématiques, physique, chimie / Plutôt froid ou plutôt chaud ?', 'description': 'T’es-tu déjà demandé quelle est la température corporelle d’un chien, celle atteinte par la lave lors d’une éruption volcanique, celle de la neige carbonique qui sort d’un extincteur, et tout un tas d’autres ? Ce jeu t’invite à deviner et classer des températures qui vont du très chaud au très froid !\n> Dès 9 ans\n> Jeu en HTML5, accessible au clavier, à la synthèse vocale, avec contrastes des couleurs', 'type': 'test', 'url': 'https://www.cite-sciences.fr/juniors/froid-chaud/plutot-froid-ou-plutot-chaud.html'}
# ==============
# {'title': 'Mathématiques, physique, chimie / Quiz « Le froid ? C’est chaud ! »', 'description': 'Teste tes connaissances sur le froid, le chaud, la chaleur, les échelles de température, les moyens de défense des animaux face au froid...\n> Dès 9 ans\n> Jeu en HTML5, accessible au clavier, à la synthèse vocale, avec contrastes des couleurs', 'type': 'test', 'url': 'https://www.cite-sciences.fr/juniors/froid-chaud/quiz.html'}
# ==============
# {'title': 'Sciences de la vie et de la Terre / Les animaux face au froid', 'description': 'Endotherme, ectotherme : voilà des mots bien barbares ! C’est pourtant comme ça qu’on répartit les animaux selon que leur température est produite par leur organisme ou pas. Après ce jeu, ces mots n’auront plus de secret pour toi et tu sauras aussi quels sont leurs moyens de défense face au froid.\n> Dès 9 ans\n> Jeu en HTML5, accessible au clavier, à la synthèse vocale, avec contrastes des couleurs', 'type': 'test', 'url': 'https://www.cite-sciences.fr/juniors/froid-chaud/les-animaux-face-au-froid.html'}
# ==============
# {'title': 'Sciences de la vie et de la Terre / Quiz « Le froid ? C’est chaud ! »', 'description': 'Teste tes connaissances sur le froid, le chaud, la chaleur, les échelles de température, les moyens de défense des animaux face au froid...\n> Dès 9 ans\n> Jeu en HTML5, accessible au clavier, à la synthèse vocale, avec contrastes des couleurs', 'type': 'test', 'url': 'https://www.cite-sciences.fr/juniors/froid-chaud/quiz.html'}
# ==============
# {'title': 'Sciences de la vie et de la Terre / Écoutez-moi !', 'description': 'Pour communiquer, les chiens et les chats vocalisent de plusieurs façons. Sauras-tu retrouver ce que signifie les différents aboiements, miaulements, grognements, etc. ?\n> Dès 7 ans\n> Jeu en HTML5, accessible au clavier, avec contraste de couleurs', 'type': 'test', 'url': 'https://www.cite-sciences.fr/au-programme/expos-temporaires/chiens-et-chats/quiz-ecoutez-moi/'}
# ==============
# {'title': 'Sciences de la vie et de la Terre / Milieux terrestre et marin des Galápagos', 'description': 'Sauras-tu répartir 28 espèces animales et végétales des îles Galápagos dans leur milieu terrestre ou marin, en évitant les pièges ?\n> Dès 8 ans\n> Jeu en HTML5, accessible au clavier, à la synthèse vocale avec contrastes des couleurs', 'type': 'test', 'url': 'https://www.cite-sciences.fr/juniors/darwin-galapagos/milieux-et-reseaux-alimentaires.html'}
# ==============
# {'title': 'Sciences de la vie et de la Terre / Réseaux alimentaires', 'description': 'Retrouve les prédateurs de 28 espèces animales et végétales des îles Galápagos et construis un réseau alimentaire.\n> Dès 8 ans\n> Jeu en HTML5, accessible au clavier, à la synthèse vocale avec contrastes des couleurs', 'type': 'test', 'url': 'https://www.cite-sciences.fr/juniors/darwin-galapagos/milieux-et-reseaux-alimentaires.html'}
# ==============
# {'title': 'Sciences de la vie et de la Terre / Classification emboîtée des animaux', 'description': 'Observe bien les caractères de 22 animaux des îles Galápagos et classe-les dans des boîtes de plus en plus fines, puis établis leurs liens de parenté dans un arbre.\n> Dès 9 ans\n> Jeu en HTML5, accessible au clavier, à la synthèse vocale avec contrastes des couleurs', 'type': 'test', 'url': 'https://www.cite-sciences.fr/juniors/darwin-galapagos/classification-emboitee-des-animaux.html'}
# ==============
# {'title': "Sciences de la vie et de la Terre / L'évolution et la sélection naturelle", 'description': "Retrouve quels caractères avantageux ont permis aux iguanes marins, aux tortues géantes, aux pinsons de Darwin de s'adapter à des environnements particuliers.\n> Dès 8 ans\n> Jeu en HTML5, accessible au clavier, à la synthèse vocale avec contrastes des couleurs", 'type': 'test', 'url': 'https://www.cite-sciences.fr/juniors/darwin-galapagos/evolution-et-selection-naturelle.html'}
# ==============
# {'title': 'Sciences de la vie et de la Terre / Quiz « Sur les pas de Darwin aux Galápagos »', 'description': "Teste tes connaissances sur la faune et la flore des Galápagos, les prédateurs de 28 espèces animales et végétales de l'archipel, la classification des animaux et l'évolution.\n> Dès 9 ans\n> Jeu en HTML5, accessible au clavier, à la synthèse vocale avec contrastes des couleurs", 'type': 'test', 'url': 'https://www.cite-sciences.fr/juniors/darwin-galapagos/quiz.html'}
# ==============
# {'title': 'Sciences de la vie et de la Terre / La planète Terre', 'description': "Une série de cartes et schémas animés pour savoir à quoi ressemble l'intérieur de la Terre, ce que sont la tectonique des plaques et la dérive des continents et pour situer les volcans et les séismes par rapport aux plaques.\n> Dès 9 ans", 'type': 'test', 'url': 'https://www.fondation-lamap.org/sites/default/files/upload/media/minisites/projet_risques/animations-html/terre.html'}
# ==============
# {'title': 'Sciences de la vie et de la Terre / Les volcans', 'description': "Déclenche plusieurs types d'éruptions volcaniques en faisant varier la viscosité du magma et la quantité de gaz et observe bien les éruptions et la forme des volcans.\n> Dès 9 ans", 'type': 'test', 'url': 'https://www.fondation-lamap.org/sites/default/files/upload/media/minisites/projet_risques/animations-html/volcans.html'}
# ==============
# {'title': 'Sciences de la vie et de la Terre / Les séismes', 'description': "Avec cette simulation, déclenche des séismes en jouant sur la profondeur du foyer, la magnitude du séisme et le type de région touchée. Tu comprendras alors que la dangerosité d'un séisme dépend de ces trois paramètres.\n> Dès 9 ans", 'type': 'test', 'url': 'https://www.fondation-lamap.org/sites/default/files/upload/media/minisites/projet_risques/animations-html/seismes.html'}
# ==============
# {'title': 'Sciences de la vie et de la Terre / Les tsunamis', 'description': 'Dans la première partie de ce module, expérimente ce qui crée une vague et observe la forme et le déplacement des vagues. Dans la seconde partie, observe comment se forme un tsunami.\n> Dès 9 ans', 'type': 'test', 'url': 'https://www.fondation-lamap.org/sites/default/files/upload/media/minisites/projet_risques/animations-html/tsunamis.html'}
# ==============
# {'title': 'Sciences de la vie et de la Terre / Vivre avec le risque', 'description': 'Ce joli film d’animation retrace l’histoire des catastrophes passées, explique pourquoi les peuples continuent à vivre dans les zones à risque et aborde la prévention des catastrophes dues aux volcans, séismes et tsunamis.\n> Dès 7 ans\xa0', 'type': 'test', 'url': 'https://www.fondation-lamap.org/sites/default/files/upload/media/minisites/projet_risques/animations-html/vivre-avec-le-risque.html'}
# ==============
# {'title': 'Sciences de la vie et de la Terre / Le quiz "Quand la Terre gronde"', 'description': "Teste tes connaissances sur tous les sujets abordés dans l'application Quand la Terre gronde (prévention des volcans, séismes, tsunamis). N'hésite pas à rejouer car les 10 questions posées ne sont pas toujours les mêmes !\n> Dès 9 ans", 'type': 'test', 'url': 'https://www.fondation-lamap.org/sites/default/files/upload/media/minisites/projet_risques/animations-html/quiz.html'}
# ==============
# {'title': 'Corps humain, santé / La machine à déclaration', 'description': 'Aide-toi de cette machine pour écrire un poème et déclarer ta flamme à ton amoureux ou ton amoureuse.\n> Dès 9 ans\n> Jeu en HTML5, accessible au clavier, à la synthèse vocale avec contrastes des couleurs', 'type': 'test', 'url': 'http://www.cite-sciences.fr/au-programme/expos-temporaires/zizi-sexuel/machine-a-declarations/'}
# ==============
# {'title': 'Corps humain, santé / Le quiz Cerveau', 'description': 'En 10 questions, teste tes connaissances sur le fonctionnement du cerveau humain !\n> Dès 12 ans\n> Jeu en HTML5, accessible au clavier, à la synthèse vocale avec contrastes des couleurs', 'type': 'test', 'url': 'http://www.cite-sciences.fr/au-programme/expos-permanentes/expos-permanentes-dexplora/cerveau/quiz/'}
# ==============
# {'title': 'Corps humain, santé / Concours de voix', 'description': 'Fais chanter un des chanteurs le plus fort possible et découvre les six tessitures de voix : basse, baryton, ténor, alto, mezzo et soprano.\n> Dès 8 ans\n> Jeu en HTML5, accessible au clavier, à la synthèse vocale avec contrastes des couleurs', 'type': 'test', 'url': 'http://www.cite-sciences.fr/fr/a-visiter/expositions-temporaires/la-voix/jeux/jeu-1/index.php'}
# ==============
# {'title': 'Corps humain, santé / Le mémory des baisers', 'description': 'Avec les amis de Titeuf, retrouve les paires de baisers et écoute leur bruit : baveux, timide, passion, métal...\n> Dès 6 ans\n> Jeu en HTML5, accessible au clavier, à la synthèse vocale avec contrastes des couleurs', 'type': 'test', 'url': 'http://www.cite-sciences.fr/au-programme/expos-temporaires/zizi-sexuel/memory-des-baisers/'}
# ==============
# {'title': 'Corps humain, santé / Le quiz du zizi sexuel', 'description': 'Teste tes connaissances sur la sexualité avec Titeuf et Nadia et amuse-toi des dessins humoristiques de Zep.\n> Dès 9 ans\n> Jeu en HTML5, accessible au clavier, à la synthèse vocale avec contrastes des couleurs', 'type': 'test', 'url': 'http://www.cite-sciences.fr/archives/francais/ala_cite/expositions/zizi-sexuel/Quiz_zizi/quiz.swf'}
# ==============
# {'title': 'Corps humain, santé / Les 10 bons trucs à savoir', 'description': "10 questions pour être respectueux de l'autre et se sentir bien dans sa peau avant de faire l'amour.\n> Dès 11 ans\n> Jeu en HTML5, accessible au clavier, à la synthèse vocale avec contrastes des couleurs", 'type': 'test', 'url': 'http://www.cite-sciences.fr/au-programme/expos-temporaires/zizi-sexuel/10-bons-trucs-a-savoir/'}
# ==============
# {'title': 'Arts, science et société / Gautier, fils de marchand', 'description': 'Pars en voyage avec le jeune Gautier, fils de marchand, et découvre les transports, les voyageurs, le commerce, les échanges de marchandises et la diffusion des savoirs en Europe et en Méditerranée au 13e siècle.\n> Dès 9 ans\n> Jeu en HTML5, accessible au clavier, à la synthèse vocale avec contrastes des couleurs', 'type': 'test', 'url': 'http://www.cite-sciences.fr/juniors/moyen-age/gautier-fils-de-marchand.html'}
# ==============
# {'title': 'Arts, science et société / Le quiz Moyen Âge', 'description': "Dix questions tirées aléatoirement parmi une soixantaine t'invitent à tester tes connaissances sur le second Moyen Âge : vie à la campagne et dans les villes, commerce, transports, diffusion des savoirs, travail des paysans, des artisans, des marchands...\n> Dès 9 ans\n> Jeu en HTML5, accessible au clavier, à la synthèse vocale avec contrastes des couleurs", 'type': 'test', 'url': 'http://www.cite-sciences.fr/juniors/moyen-age/quiz.html'}
# ==============
# {'title': 'Arts, science et société / La riskothèque', 'description': 'Une série de photographies te présentent des objets servant à éviter ou à réduire les risques. Sauras-tu classer ces objets dans les différentes catégories de risques ?\n> Dès 9 ans\n> Jeu en HTML5, accessible au clavier, à la synthèse vocale avec contrastes des couleurs', 'type': 'test', 'url': 'https://www.cite-sciences.fr/au-programme/expos-temporaires/risque/riskotheque/'}
# ==============
# {'title': 'Arts, science et société / Riskorama', 'description': 'En 28 questions rigolotes, évalue ton comportement face au risque et imprime une illustration qui te ressemble !\n> Dès 8 ans\n> Jeu en HTML5, accessible au clavier, à la synthèse vocale avec contrastes des couleurs', 'type': 'test', 'url': 'http://www.cite-sciences.fr/risque-audace/1/'}
# ==============
# {'title': 'Arts, science et société / Carte des accents', 'description': 'Écoute attentivement les accents de plusieurs personnes francophones et retrouve le plus vite possible de quelle région de France ou du monde elles sont originaires.\n> Dès 9 ans\n> Jeu en HTML5, accessible au clavier, à la synthèse vocale avec contrastes des couleurs', 'type': 'test', 'url': 'http://www.cite-sciences.fr/au-programme/expos-temporaires/la-voix/jeux/jeu-2/instructions.php'}
# ==============
# {'title': 'Arts, science et société / Valorisez votre temps', 'description': 'Si tu aides tes parents en effectuant des tâches domestiques (ménage, rangement, courses...), cette application te permet de calculer en euros la valeur de ton travail. Un bon moyen pour faire valoir ton argent de poche !\n> Dès 10 ans\n> Jeu en HTML5, accessible au clavier, à la synthèse vocale avec contrastes des couleurs', 'type': 'test', 'url': 'http://www.cite-sciences.fr/au-programme/expos-temporaires/economie-krach-boom-mue/valorisez-votre-temps/'}
# ==============
# {'title': 'Arts, science et société / Les manuscrits de Léonard', 'description': 'Léonard de Vinci, artiste et ingénieur du 15e siècle a laissé de somptueux manuscrits dans lesquels il notait ses idées et dessinait ses observations. Cette application permet d’explorer\xa0 10 manuscrits avec des outils de zoom, d’inversion, de commentaires.\n> Dès 11 ans', 'type': 'test', 'url': 'http://www.cite-sciences.fr/au-programme/expos-temporaires/leonard-de-vinci/manuscrits-leonard-vinci/acc/manuscrits.html'}
# ==============
